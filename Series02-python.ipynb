# %% [markdown]
# #IEAP-python-series02: Sinusoids, from math to code
#
# In this prject, we will plot how to ploy sinus waves using python
#
# The maths involved with this are
#
# $y(t) = A \sin(\omega t + \varphi)$

# %%
import numpy as np
import matplotlib.pyplot as plt
